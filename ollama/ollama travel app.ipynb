# %%
import requests
import json
from datetime import datetime, timedelta

class TripPlanner:
    def __init__(self, ollama_base_url="http://localhost:11434"):
        self.ollama_base_url = ollama_base_url
        
    def generate_prompt(self, destination, num_days):
        return f"""Create a detailed {num_days}-day trip itinerary for {destination}. 
        Please provide a day-by-day breakdown including:
        - Morning activities and attractions
        - Afternoon activities
        - Evening activities and dinner suggestions
        - Must-visit locations
        - Local food recommendations
        - Transportation tips
        
        
        Please write it in a natural, conversational style that's easy to read.
        Make it detailed but friendly, as if you're suggesting this itinerary to a friend."""

    def get_itinerary(self, destination, num_days):
        prompt = self.generate_prompt(destination, num_days)
        
        try:
            # Test connection to Ollama first
            try:
                requests.get(f"{self.ollama_base_url}/api/tags")
            except requests.exceptions.ConnectionError:
                return "Error: Cannot connect to Ollama. Please ensure Ollama is running (ollama run mistral)"

            # Use the correct API endpoint for chat completion
            response = requests.post(
                f"{self.ollama_base_url}/api/chat",
                json={
                    "model": "llama3.2:1b",
                    "messages": [
                        {
                            "role": "user",
                            "content": prompt
                        }
                    ],
                    "stream": False
                }
            )
            
            if response.status_code == 200:
                response_text = response.json().get('message', {}).get('content', '')
                return self.format_output(response_text, num_days, destination)
            else:
                return (f"Error: Unable to generate itinerary. Status code: {response.status_code}\n"
                       f"Make sure you have pulled the mistral model using 'ollama pull mistral'")
                
        except requests.exceptions.RequestException as e:
            return f"Error connecting to Ollama: {str(e)}\nPlease ensure Ollama is running on {self.ollama_base_url}"

    def format_output(self, text, num_days, destination):
        """Format the response in a human-readable way"""
        # Add a decorative header
        formatted_output = [
            "╔══════════════════════════════════════════════════╗",
            f"             Your {num_days}-Day Trip to {destination.title()}",
            "╚══════════════════════════════════════════════════╝\n"
        ]

        # Split the text into days if it contains day markers
        days = []
        current_day = []
        
        for line in text.split('\n'):
            line = line.strip()
            if not line:
                continue
                
            # Check for day markers in various formats
            day_starts = [f"Day {i}:" for i in range(1, num_days + 1)] + [f"Day {i}" for i in range(1, num_days + 1)]
            
            if any(line.startswith(day) for day in day_starts):
                if current_day:
                    days.append('\n'.join(current_day))
                current_day = [line]
            else:
                current_day.append(line)
                
        if current_day:
            days.append('\n'.join(current_day))

        # If no clear day structure, split text roughly into days
        if len(days) != num_days:
            text_chunks = text.split('\n\n')
            days = []
            current_chunk = []
            chunk_size = len(text_chunks) // num_days
            
            for i, chunk in enumerate(text_chunks):
                current_chunk.append(chunk)
                if (i + 1) % chunk_size == 0 and len(days) < num_days:
                    days.append('\n'.join(current_chunk))
                    current_chunk = []

        # Format each day
        for i, day_content in enumerate(days, 1):
            formatted_output.extend([
                f"\n{'═' * 50}",
                f"🌅 Day {i}",
                f"{'═' * 50}\n",
                day_content.strip(),
                "\n"
            ])

        # Add footer with travel tips
        formatted_output.extend([
            "╔══════════════════════════════════════════════════╗",
            "                  Travel Tips 🎯",
            "╚══════════════════════════════════════════════════╝",
            "• Remember to check opening hours for attractions",
            "• Keep local emergency numbers handy",
            "• Respect local customs and traditions",
            "• Stay hydrated and carry weather-appropriate gear",
            "• Have a fantastic trip! 🌟"
        ])

        return '\n'.join(formatted_output)

def main():
    print("\n🌎 Welcome to Your Personal Trip Planner! 🌎\n")
    
    destination = input("Where would you like to go? ")
    while True:
        try:
            num_days = int(input("How many days will you be traveling? "))
            if num_days > 0:
                break
            print("Please enter a positive number of days.")
        except ValueError:
            print("Please enter a valid number.")
    
    print("\n✨ Creating your personalized travel itinerary... ✨")
    planner = TripPlanner()
    print("\n" + planner.get_itinerary(destination, num_days))

if __name__ == "__main__":
    main()
# Out:
# 🌎 Welcome to Your Personal Trip Planner! 🌎
# Where would you like to go?  Patna
# How many days will you be traveling?  3
# ✨ Creating your personalized travel itinerary... ✨
#
# ╔══════════════════════════════════════════════════╗
#              Your 3-Day Trip to Patna
# ╚══════════════════════════════════════════════════╝
#
#
# ══════════════════════════════════════════════════
# 🌅 Day 1
# ══════════════════════════════════════════════════
#
# Patna! What a fantastic destination to explore. I've put together a 3-day trip itinerary for you that'll help you make the most of your visit. Get ready to discover the rich history, stunning temples, and vibrant culture of Bihar's capital city.
# **Day 1: Explore Patna's Historic Sites**
#  Morning Activities:
# * Start with breakfast at **The Caffeine Factory**, a popular spot for coffee, pastries, and delicious desserts.
# * Head over to the **Rajar Lake**, a beautiful lake that served as the capital of India during British rule. Take a leisurely stroll around the lake, rent a boat if you want to, or simply enjoy the scenic views.
# Afternoon Activities:
# * Visit the **Sarnath Buddhist Stupa**, a UNESCO World Heritage Site and one of the most famous Buddhist sites in India.
# * Stop by the **Jewel Park Zoo**, home to over 500 animals from around the world. It's a great place for families or those who love animals.
# Evening Activities:
# * Enjoy dinner at **Tamarind Tree Cafe & Restaurant**, which serves a range of Indian and international dishes in a cozy atmosphere.
# * End the day with a visit to the **Patna Museum**, which showcases the city's history, art, and culture.
# Must-visit Locations:
# * Rajar Lake
# * Sarnath Buddhist Stupa
# * Jewel Park Zoo
# Local Food Recommendations:
# - Try the famous **Patna-style** vegetable dish called **Sagai** at local restaurants.
# - Visit a street food stall to try some delicious **Aloo Tikki**, a popular Patna snack.
# Transportation Tips:
#
#
#
# ══════════════════════════════════════════════════
# 🌅 Day 2
# ══════════════════════════════════════════════════
#
# * Use **Taxis** or **Ride-hailing apps** like Ola or Uber to get around the city.
# * Take an **Auto-rickshaw** tour of the city for a fun and affordable way to explore.
# * Consider purchasing a **Smart Card**, which can be used for public transportation, taxis, and ride-hailing services.
# **Day 2: Discover Patna's Street Food Scene**
# Morning Activities:
# * Start your day with breakfast at **The Spice Mill Cafe & Restaurant**, known for its delicious Indian cuisine.
# * Visit the **Patna Fruit Market**, where you can sample a variety of fruits, including bananas, mangoes, and papayas.
# Afternoon Activities:
# * Explore the **Rajgir Archaeological Park**, which features ancient ruins, museums, and a zoo.
# * Take a stroll through the **Durgapuri Market**, one of the largest fruit markets in India.
# Evening Activities:
# * Enjoy dinner at **Jama Masjid Restaurant & Café**, serving Indian cuisine with a modern twist.
# * End the day with a visit to the **Patna City Railway Station**, which offers stunning views of the city and its surroundings.
# Must-visit Locations:
# * Rajgir Archaeological Park
# * Durgapuri Market
# Local Food Recommendations:
# - Try some delicious **Patna-style** street food at stalls like **Bhule** or **Chotai**.
# - Visit a local market to try some fresh fruits, vegetables, and other products.
# Transportation Tips:
#
#
#
# ══════════════════════════════════════════════════
# 🌅 Day 3
# ══════════════════════════════════════════════════
#
# * Use public transportation, including buses and auto-rickshaws, to get around the city.
# * Consider purchasing a **Smart Card**, which can be used for public transportation, taxis, and ride-hailing services.
# * Be sure to tip your drivers (around 10-15% of the fare).
# **Day 3: Visit Patna's Historical Sites**
# Morning Activities:
# * Start your day with breakfast at **The Café**, a cozy spot serving delicious baked goods and coffee.
# * Visit the **Nalanda University Museum**, which showcases the university's history, art, and culture.
# Afternoon Activities:
# * Explore the **Bharatiya Janata Dal (BJD) Bhavan**, an important historical building that serves as the party headquarters of the BJD.
# * Take a stroll through the **Patna Railway Station Square**, which features beautiful gardens and monuments.
# Evening Activities:
# * Enjoy dinner at **Lal Mahal Restaurant & Café**, serving traditional Indian cuisine with a modern twist.
# * End the day with a visit to the **Sri Ramakrishna Math**, a popular pilgrimage site and one of the largest Hindu temples in India.
# Must-visit Locations:
# * Nalanda University Museum
# * Bharatiya Janata Dal (BJD) Bhavan
# Local Food Recommendations:
# - Try some delicious **Patna-style** street food at stalls like **Kesarwala** or **Mohanlal**.
# - Visit a local market to try some fresh fruits, vegetables, and other products.
# Transportation Tips:
#
#
# ╔══════════════════════════════════════════════════╗
#                   Travel Tips 🎯
# ╚══════════════════════════════════════════════════╝
# • Remember to check opening hours for attractions
# • Keep local emergency numbers handy
# • Respect local customs and traditions
# • Stay hydrated and carry weather-appropriate gear
# • Have a fantastic trip! 🌟

# %%
import gradio as gr
import requests
import json

class TripPlanner:
    def __init__(self, ollama_base_url="http://localhost:11434"):
        self.ollama_base_url = ollama_base_url
        
    def generate_prompt(self, destination, num_days):
        return f"""Create a detailed {num_days}-day trip itinerary for {destination}. \
        Please provide a day-by-day breakdown including:\
        - Morning activities and attractions\
        - Afternoon activities\
        - Evening activities and dinner suggestions\
        - Must-visit locations\
        - Local food recommendations\
        - Transportation tips\
        - Total budget according to the day with category cheap and expensive also according to the persons.
        \n        Please write it in a natural, conversational style that's easy to read.\
        Make it detailed but friendly, as if you're suggesting this itinerary to a friend."""

    def get_itinerary(self, destination, num_days):
        prompt = self.generate_prompt(destination, num_days)
        
        try:
            # Test connection to Ollama first
            try:
                requests.get(f"{self.ollama_base_url}/api/tags")
            except requests.exceptions.ConnectionError:
                return "Error: Cannot connect to Ollama. Please ensure Ollama is running (ollama run mistral)"

            # Use the correct API endpoint for chat completion
            response = requests.post(
                f"{self.ollama_base_url}/api/chat",
                json={
                    "model": "llama3.2:1b",
                    "messages": [
                        {
                            "role": "user",
                            "content": prompt
                        }
                    ],
                    "stream": False
                }
            )
            
            if response.status_code == 200:
                response_text = response.json().get('message', {}).get('content', '')
                return self.format_output(response_text, num_days, destination)
            else:
                return (f"Error: Unable to generate itinerary. Status code: {response.status_code}\n"
                       f"Make sure you have pulled the mistral model using 'ollama pull mistral'")
                
        except requests.exceptions.RequestException as e:
            return f"Error connecting to Ollama: {str(e)}\nPlease ensure Ollama is running on {self.ollama_base_url}"

    def format_output(self, text, num_days, destination):
        formatted_output = [
            f"Your {num_days}-Day Trip to {destination.title()}\n",
            "=" * 50
        ]

        days = []
        current_day = []

        for line in text.split('\n'):
            line = line.strip()
            if not line:
                continue

            day_starts = [f"Day {i}:" for i in range(1, num_days + 1)] + [f"Day {i}" for i in range(1, num_days + 1)]

            if any(line.startswith(day) for day in day_starts):
                if current_day:
                    days.append('\n'.join(current_day))
                current_day = [line]
            else:
                current_day.append(line)

        if current_day:
            days.append('\n'.join(current_day))

        if len(days) != num_days:
            text_chunks = text.split('\n\n')
            days = []
            current_chunk = []
            chunk_size = len(text_chunks) // num_days

            for i, chunk in enumerate(text_chunks):
                current_chunk.append(chunk)
                if (i + 1) % chunk_size == 0 and len(days) < num_days:
                    days.append('\n'.join(current_chunk))
                    current_chunk = []

        for i, day_content in enumerate(days, 1):
            formatted_output.extend([
                f"\nDay {i}\n",
                "-" * 50,
                day_content.strip(),
                "\n"
            ])

        formatted_output.extend([
            "\nTravel Tips:\n",
            "• Remember to check opening hours for attractions",
            "• Keep local emergency numbers handy",
            "• Respect local customs and traditions",
            "• Stay hydrated and carry weather-appropriate gear",
            "• Have a fantastic trip!"
        ])

        return '\n'.join(formatted_output)


def interact_with_trip_planner(destination, num_days):
    try:
        num_days = int(num_days)
        if num_days <= 0:
            return "Please enter a positive number of days."
    except ValueError:
        return "Invalid number of days. Please enter a valid number."

    planner = TripPlanner()
    return planner.get_itinerary(destination, num_days)


def main():
    iface = gr.Interface(
        fn=interact_with_trip_planner,
        inputs=[
            gr.Textbox(label="Destination", placeholder="Enter your travel destination"),
            gr.Textbox(label="Number of Days", placeholder="Enter number of days")
        ],
        outputs=gr.Textbox(label="Travel Itinerary"),
        title="Trip Planner",
        description="Generate a detailed trip itinerary for your destination."
    )

    iface.launch()


if __name__ == "__main__":
    main()
# Out:
# Running on local URL:  http://127.0.0.1:7862
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
